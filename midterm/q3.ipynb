# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./UCI_heart.csv")
df.head()
# Out:
#    age  sex  trestbps  chol  fbs  restecg  thalach  exang  Heart_problem  \
# 0   63    1       145   233    1        2      150      0              0
# 1   67    1       160   286    0        2      108      1              1
# 2   67    1       120   229    0        2      129      1              1
# 3   37    1       130   250    0        0      187      0              0
# 4   41    0       130   204    0        2      172      0              0
#
#   Age_Quantile
# 0           Q4
# 1           Q4
# 2           Q4
# 3           Q1
# 4           Q1

# %%
df.dropna(inplace=True)
df.describe(include='all')
# Out:
#                age         sex    trestbps        chol         fbs  \
# count   303.000000  303.000000  303.000000  303.000000  303.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean     54.438944    0.679868  131.689769  246.693069    0.148515
# std       9.038662    0.467299   17.599748   51.776918    0.356198
# min      29.000000    0.000000   94.000000  126.000000    0.000000
# 25%      48.000000    0.000000  120.000000  211.000000    0.000000
# 50%      56.000000    1.000000  130.000000  241.000000    0.000000
# 75%      61.000000    1.000000  140.000000  275.000000    0.000000
# max      77.000000    1.000000  200.000000  564.000000    1.000000
#
#            restecg     thalach       exang  Heart_problem Age_Quantile
# count   303.000000  303.000000  303.000000     303.000000          303
# ...

# %%
import matplotlib.pyplot as plt

# %%
f_cols = ["age", "trestbps", "chol", "thalach"]
for i in range(len(f_cols) - 1):
    for j in range(i + 1, len(f_cols)):
        plt.figure()
        plt.scatter(df[f_cols[i]], df[f_cols[j]], color='blue', alpha=0.5)
        plt.title(f"Scatter Plot of {f_cols[i]} vs {f_cols[j]}")
        plt.xlabel(f_cols[i])
        plt.ylabel(f_cols[j])
        plt.show()

# Box plots for F7, F8, and F9 combinations
import seaborn as sns

f_box_cols = f_cols
for i in range(len(f_box_cols)):
    for j in range(i + 1, len(f_box_cols)):
        plt.figure()
        sns.boxplot(x=df[f_box_cols[j]], y=df[f_box_cols[i]])
        plt.title(f"Box Plot of {f_box_cols[i]} vs {f_box_cols[j]}")
        plt.xlabel(f_box_cols[j])
        plt.ylabel(f_box_cols[i])
        plt.show()
